# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint

# Import API key
#import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 619

# %%
cities_test=cities[0:10]
cities_test
# Out:
# ['vangaindrano',
#  'carbonia',
#  'dikson',
#  'quimper',
#  'alice springs',
#  'northam',
#  'lincoln',
#  'sola',
#  'vila velha',
#  'birao']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = 'https://api.openweathermap.org/data/2.5/weather?'
api_key = '3af3358df3c85ea7168b21849f0f8c7e'
units = "metric"
number=0
City=[] 
Code=[]
Cloudiness=[]    
Country=[]      
Date=[]         
Humidity=[]     
Lat=[]          
Lng=[]          
Max_Temp=[]    
Wind_Speed=[]
for city in cities:
    try:
        query_url = f"{url}appid={api_key}&q={city}&units={units}"
        weather_response = requests.get(query_url).json()
        City.append(weather_response["name"])
        Code.append(weather_response["id"])        
        Cloudiness.append(weather_response['clouds']['all'])
        Country.append(weather_response['sys']['country'])     
        Date.append(weather_response['dt'])    
        Humidity.append(weather_response['main']['humidity'])
        Lat.append(weather_response['coord']['lat'])  
        Lng.append(weather_response['coord']['lon']) 
        Max_Temp.append(weather_response['main']['temp_max'])
        Wind_Speed.append(weather_response['wind']['speed'])
        number=number+1
        code=weather_response["id"] 
        print(f"Processing Record {number} | {city} - {code}")
    except:
        print("City not found. Skipping...")
        pass
print("------------------------------")
print("Data Retrieval Complete ")
print("------------------------------")
# Out:
# Processing Record 1 | vangaindrano - 1054329
# Processing Record 2 | carbonia - 2525362
# Processing Record 3 | dikson - 1507390
# Processing Record 4 | quimper - 2984701
# Processing Record 5 | alice springs - 2077895
# Processing Record 6 | northam - 2641434
# Processing Record 7 | lincoln - 5072006
# Processing Record 8 | sola - 643453
# Processing Record 9 | vila velha - 6320062
# Processing Record 10 | birao - 240210
# Processing Record 11 | ixtapa - 4004293
# Processing Record 12 | qaanaaq - 3831208
# Processing Record 13 | usinsk - 863061
# Processing Record 14 | sitka - 4267710
# Processing Record 15 | albany - 5106834
# Processing Record 16 | cherskiy - 2126199
# Processing Record 17 | atuona - 4020109
# Processing Record 18 | half moon bay - 5354943
# Processing Record 19 | saint-philippe - 6138908
# Processing Record 20 | hobart - 2163355
# Processing Record 21 | rikitea - 4030556
# Processing Record 22 | ancud - 3899695
# Processing Record 23 | ushuaia - 3833367
# Processing Record 24 | georgetown - 3378644
# Processing Record 25 | egvekinot - 4031742
# Processing Record 26 | srednekolymsk - 2121025
# Processing Record 27 | kapaa - 5848280
# Processing Record 28 | oktyabrskiy - 515873
# Processing Record 29 | torbay - 6167817
# Processing Record 30 | new norfolk - 2155415
# Processing Record 31 | ribeira grande - 3372707
# Processing Record 32 | chapais - 5919850
# Processing Record 33 | carlisle - 2653775
# Processing Record 34 | tasiilaq - 3424607
# Processing Record 35 | sotnikovskoye - 490108
# Processing Record 36 | los llanos de aridane - 2514651
# City not found. Skipping...
# Processing Record 37 | sao joao da barra - 3448903
# Processing Record 38 | cabo san lucas - 3985710
# Processing Record 39 | busselton - 2075265
# Processing Record 40 | baykit - 1510689
# Processing Record 393 | san cristobal - 3652462
# Processing Record 394 | san jose de guanipa - 3628142
# Processing Record 395 | picton - 2153259
# Processing Record 396 | comodoro rivadavia - 3860443
# Processing Record 397 | udarnyy - 826996
# Processing Record 398 | la trinitaria - 3524527
# Processing Record 399 | meulaboh - 1214488
# Processing Record 400 | ambilobe - 1082243
# Processing Record 401 | brandon - 5226489
# Processing Record 402 | coquimbo - 3893629
# Processing Record 403 | te anau - 2181625
# Processing Record 404 | bongandanga - 218229
# Processing Record 405 | risti - 588157
# Processing Record 406 | knysna - 988698
# Processing Record 407 | tessalit - 2449893
# Processing Record 408 | namtsy - 2019488
# City not found. Skipping...
# Processing Record 409 | mindelo - 2739997
# Processing Record 410 | aquiraz - 3407407
# Processing Record 411 | sao miguel do araguaia - 3448455
# Processing Record 412 | provideniya - 4031574
# Processing Record 413 | la rioja - 3848950
# Processing Record 414 | tharad - 1254638
# Processing Record 415 | bali - 1784642
# Processing Record 416 | padang - 1633419
# Processing Record 417 | panguna - 2088659
# Processing Record 418 | milkovo - 727030
# Processing Record 419 | kaa-khem - 1500973
# Processing Record 420 | gwembe - 917011
# Processing Record 421 | tommot - 2015179
# Processing Record 422 | grand gaube - 934479
# Processing Record 423 | sur - 286245
# Processing Record 424 | magadan - 2123628
# Processing Record 425 | dali - 1814093
# City not found. Skipping...
# Processing Record 426 | sonkovo - 490637
# Processing Record 427 | adrar - 2508813
# Processing Record 428 | lana - 3175177
# Processing Record 429 | corinto - 3465512
# Processing Record 430 | clyde river - 5924351
# City not found. Skipping...
# Processing Record 431 | makat - 608872
# Processing Record 432 | ludvika - 2693759
# Processing Record 433 | chute-aux-outardes - 5922281
# Processing Record 434 | bani - 1695357
# Processing Record 435 | marolambo - 1060007
# Processing Record 436 | langgons - 2880672
# City not found. Skipping...
# Processing Record 437 | dhidhdhoo - 1337612
# Processing Record 438 | unnao - 1253747
# Processing Record 439 | fortuna - 2517679
# City not found. Skipping...
# Processing Record 440 | monywa - 1308522
# Processing Record 441 | hamilton - 5969785
# Processing Record 442 | dolores - 3435038
# Processing Record 443 | saint-denis - 2980916
# Processing Record 444 | san ramon de la nueva oran - 3836620
# Processing Record 445 | nikita - 711527
# Processing Record 446 | chicama - 3698359
# City not found. Skipping...
# Processing Record 447 | cherdyn - 569359
# Processing Record 448 | rosario oeste - 3450872
# Processing Record 449 | killybegs - 2963295
# Processing Record 450 | labuan - 1733782
# Processing Record 451 | mecca - 104515
# Processing Record 452 | chumikan - 2025256
# Processing Record 453 | ilhabela - 3461425
# Processing Record 454 | pobe - 2392108
# Processing Record 455 | minna - 2330100
# Processing Record 456 | kushiro - 2129072
# Processing Record 457 | san juan - 3837213
# Processing Record 458 | betim - 3470044
# Processing Record 459 | port macquarie - 2152659
# Processing Record 460 | huntington beach - 5358705
# Processing Record 461 | karratha - 6620339
# Processing Record 462 | namibe - 3347019
# Processing Record 463 | pyapon - 1299237
# Processing Record 464 | atherton - 2656847
# Processing Record 465 | ribeirao branco - 3451362
# Processing Record 466 | boa vista - 3664980
# Processing Record 467 | garowe - 58933
# Processing Record 468 | sancti spiritus - 3540667
# Processing Record 469 | campos belos - 3467687
# Processing Record 470 | anacortes - 5785657
# City not found. Skipping...
# Processing Record 471 | san antonio - 3872395
# Processing Record 472 | wilmington - 4145381
# City not found. Skipping...
# Processing Record 473 | shinuhayr - 174769
# Processing Record 474 | voiron - 2967758
# Processing Record 475 | rabo de peixe - 3372745
# Processing Record 476 | antofagasta - 3899539
# Processing Record 477 | nara - 1855612
# Processing Record 478 | breytovo - 571634
# Processing Record 479 | warrington - 2634739
# Processing Record 480 | sokoni - 901344
# Processing Record 481 | buraydah - 107304
# Processing Record 482 | nivala - 644509
# Processing Record 483 | boleslawiec - 3102987
# Processing Record 484 | boajibu - 2410040
# Processing Record 485 | cambara - 3467985
# Processing Record 486 | laurel - 5661766
# Processing Record 487 | rosetta - 350203
# City not found. Skipping...
# Processing Record 488 | abu dhabi - 292968
# Processing Record 489 | wahiawa - 5853992
# Processing Record 490 | frontino - 3682313
# Processing Record 491 | nove mesto nad metuji - 3069466
# Processing Record 492 | lata - 1253628
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 493 | ust-kuyga - 2013921
# Processing Record 494 | bela vista de goias - 3470164
# Processing Record 495 | natitingou - 2392601
# Processing Record 496 | peace river - 6100069
# Processing Record 497 | erenhot - 2037485
# City not found. Skipping...
# Processing Record 498 | wagar - 4069458
# Processing Record 499 | mandalgovi - 2030065
# Processing Record 500 | marystown - 6067472
# City not found. Skipping...
# Processing Record 501 | micheweni - 153955
# City not found. Skipping...
# Processing Record 502 | mount isa - 2065594
# Processing Record 503 | richards bay - 962367
# Processing Record 504 | maxixe - 1039536
# Processing Record 505 | presidencia roque saenz pena - 3840300
# Processing Record 506 | wanning - 3220813
# City not found. Skipping...
# Processing Record 507 | taltal - 3870243
# Processing Record 508 | ikalamavony - 1064258
# Processing Record 509 | aklavik - 5882953
# Processing Record 510 | ponta do sol - 3453439
# Processing Record 511 | burnie - 2173125
# Processing Record 512 | were ilu - 326259
# Processing Record 513 | faya - 110690
# Processing Record 514 | jabinyanah - 2470260
# Processing Record 515 | moreni - 672862
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 516 | pushkar - 1259148
# Processing Record 517 | ostersund - 2685750
# Processing Record 518 | takoradi - 2294915
# Processing Record 519 | nizhniy kuranakh - 2019135
# City not found. Skipping...
# Processing Record 520 | gondar - 2736041
# Processing Record 521 | kildinstroy - 524305
# Processing Record 522 | priiskovyy - 2017632
# Processing Record 523 | ust-uda - 2013865
# Processing Record 524 | bandarbeyla - 64814
# Processing Record 525 | kvitok - 1501036
# Processing Record 526 | kenai - 5866063
# Processing Record 527 | tezu - 1254709
# Processing Record 528 | harper - 4696310
# City not found. Skipping...
# Processing Record 529 | teya - 3526662
# Processing Record 530 | mayo - 6068416
# Processing Record 531 | mabaruma - 3377301
# Processing Record 532 | macusani - 3935624
# Processing Record 533 | bachaquero - 3648698
# Processing Record 534 | cuenca - 3124132
# Processing Record 535 | klaksvik - 2618795
# Processing Record 536 | isangel - 2136825
# Processing Record 537 | sisimiut - 3419842
# Processing Record 538 | aswan - 359792
# City not found. Skipping...
# Processing Record 539 | wuwei - 1803936
# Processing Record 540 | strezhevoy - 1490796
# Processing Record 541 | vostok - 2013279
# Processing Record 542 | pochutla - 3517970
# Processing Record 543 | williams lake - 6182212
# Processing Record 544 | shingu - 1847947
# City not found. Skipping...
# Processing Record 545 | pimenta bueno - 3924908
# City not found. Skipping...
# Processing Record 546 | piedade - 3453926
# Processing Record 547 | sjoholt - 3139557
# Processing Record 548 | coxim - 3465228
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 549 | umm lajj - 100926
# City not found. Skipping...
# Processing Record 550 | santa cruz - 5393052
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_df=pd.DataFrame()
cities_df["City"]=City
cities_df["Code"]=Code
cities_df["Cloudiness"]=Cloudiness    
cities_df["Country"]=Country      
cities_df["Date"]=Date         
cities_df["Humidity"]=Humidity     
cities_df["Lat"]=Lat          
cities_df["Lng"]=Lng          
cities_df["Max Temp"]=Max_Temp    
cities_df["Wind Speed"]=Wind_Speed
cities_df.to_csv("cities.csv", 
                  encoding="utf-8", index=False, header=True)

# %%
cities_df.head()
# Out:
#             City     Code  Cloudiness Country        Date  Humidity    Lat  \
# 0   Vangaindrano  1054329          24      MG  1543808417        93 -23.35
# 1       Carbonia  2525362          20      IT  1543807200        93  39.17
# 2         Dikson  1507390           8      RU  1543808418        94  73.51
# 3        Quimper  2984701          90      FR  1543806000       100  48.00
# 4  Alice Springs  2077895          68      AU  1543806000        65 -23.70
#
#       Lng  Max Temp  Wind Speed
# 0   47.60     18.43        1.15
# 1    8.53      9.00        3.10
# 2   80.55    -26.32       12.75
# 3   -4.10     13.00        6.70
# 4  133.88     26.00        2.10

# %%
len(cities_df)
# Out:
# 550

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(cities_df["Lat"],cities_df["Max Temp"], color="b",  alpha=0.5)
plt.title("Latitude vs. Max Temperature")
plt.xlabel ("Latitude")
plt.ylabel ("Max Temp (celsius)")
plt.grid(alpha=0.2)
plt.savefig("lat_temp.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(cities_df["Lat"],cities_df["Humidity"], color="r", alpha=0.5)
plt.title("Latitude vs. Humidity")
plt.xlabel ("Latitude")
plt.ylabel ("Humidity (%)")
plt.grid(alpha=0.2)
plt.savefig("hum_temp.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(cities_df["Lat"],cities_df["Cloudiness"], color="c", alpha=0.5)
plt.title("Latitude vs. Cloudiness")
plt.xlabel ("Latitude")
plt.ylabel ("Cloudiness (%)")
plt.grid(alpha=0.2)
plt.savefig("cloud_temp.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(cities_df["Lat"],cities_df["Wind Speed"], color="g", alpha=0.5)
plt.title("Latitude vs. Wind Speed")
plt.xlabel ("Latitude")
plt.ylabel ("Wind Speed (m/s)")
plt.grid(alpha=0.2)
plt.savefig("wind_temp.png")
plt.show()
