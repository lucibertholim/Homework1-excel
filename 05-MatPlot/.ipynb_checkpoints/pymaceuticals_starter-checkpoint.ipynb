# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from matplotlib.ticker import PercentFormatter

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# Read the Mouse and Drug Data and the Clinical Trial Data
mouse_drug_data = pd.read_csv("data/mouse_drug_data.csv")
clinical_trial_data = pd.read_csv("data/clinicaltrial_data.csv")

# %%
combined_data=clinical_trial_data.merge(mouse_drug_data, how='right', on='Mouse ID')

combined_data.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites       Drug
# 0     b128          0           45.000000                 0  Capomulin
# 1     b128          5           45.651331                 0  Capomulin
# 2     b128         10           43.270852                 0  Capomulin
# 3     b128         15           43.784893                 0  Capomulin
# 4     b128         20           42.731552                 0  Capomulin

# %%
drug_list=["Capomulin", "Infubinol", "Ketapril","Placebo"]

# %% [markdown]
# ## Tumor Response to Treatment

# %%
# Store the Mean Tumor Volume Data Grouped by Drug and Timepoint 
group_combined_data=combined_data.groupby(["Drug", "Timepoint"])

# Convert to DataFrame
TV_group_combined_data_mean=pd.DataFrame(group_combined_data["Tumor Volume (mm3)"].mean()).loc[drug_list,:]

# Preview DataFrame
TV_group_combined_data_mean.head()
# Out:
#                      Tumor Volume (mm3)
# Drug      Timepoint
# Capomulin 0                   45.000000
#           5                   44.266086
#           10                  43.084291
#           15                  42.064317
#           20                  40.716325

# %%
# Store the Standard Error of Tumor Volumes Grouped by Drug and Timepoint
# Convert to DataFrame
TV_group_combined_data_sem=pd.DataFrame(group_combined_data["Tumor Volume (mm3)"].sem()).loc[drug_list,:]
# Preview DataFrame

TV_group_combined_data_sem.head()
# Out:
#                      Tumor Volume (mm3)
# Drug      Timepoint
# Capomulin 0                    0.000000
#           5                    0.448593
#           10                   0.702684
#           15                   0.838617
#           20                   0.909731

# %%
# Minor Data Munging to Re-Format the Data Frames

# Preview that Reformatting worked

formated_mean_unstack=TV_group_combined_data_mean.unstack(0)
formated_mean_unstack
# Out:
#           Tumor Volume (mm3)
# Drug               Capomulin  Infubinol   Ketapril    Placebo
# Timepoint
# 0                  45.000000  45.000000  45.000000  45.000000
# 5                  44.266086  47.062001  47.389175  47.125589
# 10                 43.084291  49.403909  49.582269  49.423329
# 15                 42.064317  51.296397  52.399974  51.359742
# 20                 40.716325  53.197691  54.920935  54.364417
# 25                 39.939528  55.715252  57.678982  57.482574
# 30                 38.769339  58.299397  60.994507  59.809063
# 35                 37.816839  60.742461  63.371686  62.420615
# 40                 36.958001  63.162824  66.068580  65.052675
# 45                 36.236114  65.755562  70.662958  68.084082

# %%
# Minor Data Munging to Re-Format the Data Frames

# Preview that Reformatting worked

formated_sem_unstack=TV_group_combined_data_sem.unstack(0)
formated_sem_unstack
# Out:
#           Tumor Volume (mm3)
# Drug               Capomulin Infubinol  Ketapril   Placebo
# Timepoint
# 0                   0.000000  0.000000  0.000000  0.000000
# 5                   0.448593  0.235102  0.264819  0.218091
# 10                  0.702684  0.282346  0.357421  0.402064
# 15                  0.838617  0.357705  0.580268  0.614461
# 20                  0.909731  0.476210  0.726484  0.839609
# 25                  0.881642  0.550315  0.755413  1.034872
# 30                  0.934460  0.631061  0.934121  1.218231
# 35                  1.052241  0.984155  1.127867  1.287481
# 40                  1.223608  1.055220  1.158449  1.370634
# 45                  1.223977  1.144427  1.453186  1.351726

# %%
# Generate the Plot (with Error Bars)
fig, ax = plt.subplots(figsize=(15,7))
formated_mean_unstack.plot(yerr=formated_sem_unstack, ax=ax)
plt.title("Tumor Response to Treatment in Mice")
plt.xlabel ("Timepoint (days)")
plt.ylabel ("Average Tumor Volume (mm3)")

ax.legend(drug_list, loc="best")
plt.xlim(0,48)
plt.ylim(min(formated_mean_unstack["Tumor Volume (mm3)"]["Capomulin"]-5),
         max(formated_mean_unstack["Tumor Volume (mm3)"]["Ketapril"]+5))

# Add in a grid for the chart
plt.grid()

# Save the Figure
plt.savefig("tumor_response_treatment.png")

# Show the Figure
plt.show()

# %% [markdown]
# ## Metastatic Response to Treatment

# %%
# Store the Mean Met. Site Data Grouped by Drug and Timepoint 
# Convert to DataFrame
MS_group_combined_data_mean=pd.DataFrame(group_combined_data["Metastatic Sites"].mean()).loc[drug_list,:]
# Preview DataFrame
MS_group_combined_data_mean.head()
# Out:
#                      Metastatic Sites
# Drug      Timepoint
# Capomulin 0                  0.000000
#           5                  0.160000
#           10                 0.320000
#           15                 0.375000
#           20                 0.652174

# %%
# Store the Standard Error associated with Met. Sites Grouped by Drug and Timepoint 

# Convert to DataFrame
MS_group_combined_data_sem=pd.DataFrame(group_combined_data["Metastatic Sites"].sem()).loc[drug_list,:]
# Preview DataFrame

MS_group_combined_data_sem.head()
# Out:
#                      Metastatic Sites
# Drug      Timepoint
# Capomulin 0                  0.000000
#           5                  0.074833
#           10                 0.125433
#           15                 0.132048
#           20                 0.161621

# %%
# Minor Data Munging to Re-Format the Data Frames
# Preview that Reformatting worked
MS_formated_mean_unstack=MS_group_combined_data_mean.unstack(0)
MS_formated_mean_unstack
# Out:
#           Metastatic Sites
# Drug             Capomulin Infubinol  Ketapril   Placebo
# Timepoint
# 0                 0.000000  0.000000  0.000000  0.000000
# 5                 0.160000  0.280000  0.304348  0.375000
# 10                0.320000  0.666667  0.590909  0.833333
# 15                0.375000  0.904762  0.842105  1.250000
# 20                0.652174  1.050000  1.210526  1.526316
# 25                0.818182  1.277778  1.631579  1.941176
# 30                1.090909  1.588235  2.055556  2.266667
# 35                1.181818  1.666667  2.294118  2.642857
# 40                1.380952  2.100000  2.733333  3.166667
# 45                1.476190  2.111111  3.363636  3.272727

# %%
# Minor Data Munging to Re-Format the Data Frames
# Preview that Reformatting worked
MS_formated_sem_unstack=MS_group_combined_data_sem.unstack(0)
MS_formated_sem_unstack
# Out:
#           Metastatic Sites
# Drug             Capomulin Infubinol  Ketapril   Placebo
# Timepoint
# 0                 0.000000  0.000000  0.000000  0.000000
# 5                 0.074833  0.091652  0.098100  0.100947
# 10                0.125433  0.159364  0.142018  0.115261
# 15                0.132048  0.194015  0.191381  0.190221
# 20                0.161621  0.234801  0.236680  0.234064
# 25                0.181818  0.265753  0.288275  0.263888
# 30                0.172944  0.227823  0.347467  0.300264
# 35                0.169496  0.224733  0.361418  0.341412
# 40                0.175610  0.314466  0.315725  0.297294
# 45                0.202591  0.309320  0.278722  0.304240

# %%
# Generate the Plot (with Error Bars)
fig, ax = plt.subplots(figsize=(15,7))
MS_formated_mean_unstack.plot(yerr=MS_formated_sem_unstack, ax=ax)
plt.title("Metastatic Response to Treatment in Mice")
plt.xlabel ("Timepoint (days)")
plt.ylabel ("Average Number of Metastatic Sites")

ax.legend(drug_list, loc="best")
plt.xlim(0,48)
plt.ylim(min(MS_formated_mean_unstack["Metastatic Sites"]["Capomulin"])-0.5,
         max(MS_formated_mean_unstack["Metastatic Sites"]["Ketapril"])+0.5)

# Add in a grid for the chart
plt.grid()

# Save the Figure
plt.savefig("number_metastatic_sites.png")

# Show the Figure
plt.show()

# %% [markdown]
# ## Survival Rates

# %%
# Store the Count of Mice Grouped by Drug and Timepoint (W can pass any metric)
# Convert to DataFrame
SR_group_combined_data_count=pd.DataFrame(group_combined_data["Mouse ID"].count()).loc[drug_list,:]

# Preview DataFrame
SR_group_combined_data_count.head()
# Out:
#                      Mouse ID
# Drug      Timepoint
# Capomulin 0                25
#           5                25
#           10               25
#           15               24
#           20               23

# %%
drug_dict={}
for drug in drug_list:
    SR_df=SR_group_combined_data_count.loc[drug]
    initial=SR_df["Mouse ID"][0]
    drug_dict[str(drug)] = SR_df["Mouse ID"]/initial

# Minor Data Munging to Re-Format the Data Frames
# Preview the Data Frame
SR_df=pd.DataFrame(drug_dict)
SR_df
# Out:
#            Capomulin  Infubinol  Ketapril  Placebo
# Timepoint
# 0               1.00       1.00      1.00     1.00
# 5               1.00       1.00      0.92     0.96
# 10              1.00       0.84      0.88     0.96
# 15              0.96       0.84      0.76     0.80
# 20              0.92       0.80      0.76     0.76
# 25              0.88       0.72      0.76     0.68
# 30              0.88       0.68      0.72     0.60
# 35              0.88       0.48      0.68     0.56
# 40              0.84       0.40      0.60     0.48
# 45              0.84       0.36      0.44     0.44

# %%
# Generate the Plot (Accounting for percentages)
fig, ax = plt.subplots(figsize=(15,7))
SR_df.plot(ax=ax)
plt.gca().yaxis.set_major_formatter(PercentFormatter(1))
plt.title("Survival after treatment in Mice")
plt.xlabel ("Timepoint (days)")
plt.ylabel ("Survival Rate (%)")

ax.legend(drug_list, loc="best")
plt.xlim(0,48)
plt.ylim(0, 1.1)

# Add in a grid for the chart
plt.grid()

# Save the Figure
plt.savefig("survival_rate.png")

# Show the Figure
plt.show()

# %% [markdown]
# ## Summary Bar Graph

# %%
summary_dict={}
for drug in drug_list:
    df=TV_group_combined_data_mean.loc[drug]
    initial=df["Tumor Volume (mm3)"][0]
    summary_dict[str(drug)] = (df["Tumor Volume (mm3)"][45]-initial)/initial
    
# Minor Data Munging to Re-Format the Data Frames
# Preview the Data Frame
summary_df=pd.DataFrame.from_dict(summary_dict, orient='index')
summary_df.rename(columns={0:"% Change"})
summary_df.sort_values(0)
# Out:
#                   0
# Capomulin -0.194753
# Infubinol  0.461235
# Placebo    0.512980
# Ketapril   0.570288

# %%
x_axis=np.arange(len(summary_df))

# %%
fig, ax = plt.subplots(figsize=(8,4))
mask1 = summary_df[0] < 0
mask2 = summary_df[0] >= 0
rects1=plt.bar(x_axis[mask1], summary_df[0][mask1], color = 'red', align="center")
rects2=plt.bar(x_axis[mask2], summary_df[0][mask2], color = 'green', align="center")
plt.title("Tumor Change after 45 days")
plt.xticks(x_axis, drug_list, rotation = 'vertical')
plt.ylabel ("Tumor Volume Change (%)")

for rect in rects1:
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width()/2., 0.99*height,
            "{:.1%}".format(height), ha='center', va='bottom')
    
for rect in rects2:
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width()/2., 0.99*height,
            "{:.1%}".format(height), ha='center', va='bottom')
    
    
plt.savefig("tv_change.png")    
plt.show()

# %% [markdown]
# # Conclusions:
# - Capumulin reduced the average tumor volume by 19,5% in 45 days of treatment in mice (from 45.0 mm3 to 36.2 mm3)
# - Mice that received Ketapril had the worst response with 57.0% of increase in tumor volume
# - By the end of 45 days of treatment, 84% of mice that received Capumulin were alive, while 36%, 44% and 44% of mice that received Infubinol, Ketapril and Placebo were alive, respectively.
# - Mice that were treated with Capomulin also presented a better repsonse in terms of metastatic sites, when compared to other treatments
# - Capomulin treatment presented better results in terms of tumor volume, metastatic sites and survival after 45 days of treatment, when compared to Infubinol, Ketapril and Placebo.
